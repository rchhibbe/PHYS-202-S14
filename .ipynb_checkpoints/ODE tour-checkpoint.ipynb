# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
g = 9.8
ell = .5
th0 = 20.*pi/180

t = np.arange(0.,10.+0.01,0.01)
theta_app = lambda t : th0*np.cos(np.sqrt(g/ell)*t)

plt.plot(t, theta_app(t),label='Approximate soution')
plt.xlabel(r'$t(seconds)$',fontsize=20)
plt.ylabel(r'$\theta (rad)$',fontsize = 20)
plt.ylim(-1,1.5)
plt.grid()
plt.legend()
plt.show()

# %%
def deriv(theta_current,t):
    g = 9.8
    ell=.5
    theta = theta_current[0]
    omega = theta_current[1]
    dtheta = omega
    domega = -(g/ell*np.sin(theta))
    return np.array([dtheta,domega])

# %%
from scipy.integrate import odeint

# %%
t = np.arange(0.,10.+.01,.01)

omega0 = 0
theta_intit = np.array([th0 ,omega0])

theta = odeint(deriv,theta_init,t)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-efcb31d9eb54> in <module>()
#       4 theta_intit = np.array([th0 ,omega0])
#       5
# ----> 6 theta = odeint(deriv,theta_init,t)
#
# NameError: name 'theta_init' is not defined

# %%
print theta.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c50bb94306b3> in <module>()
# ----> 1 print theta.shape
#
# NameError: name 'theta' is not defined

# %%
plt.plot(ttheta_app(t), 'b',label = "Approximate soultion")
plt.plot(t,theta[:,0],'r--',label = "Numerical solution")
plt.xlabel(r'$t (second)$',fontsize 20)
plt.ylabel(r'$\theta(rad$',fontsize = 20))
plt.ylim(-1,1.5)
plt.grid()
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-12-ce459252fc35>", line 3
#     plt.xlabel(r'$t (second)$',fontsize 20)
#                                          ^
# SyntaxError: invalid syntax

# %%
th0 = 50.*pi/180

theta_init = np.array([th0,omega0])
theta = odeint(deriv,theta_imit,t)

plt.plot(t,theta_app(t),'b-',label+"Approximate solution")
plt.plot(t,theta[:,0],'r--',label =" Numerical soultion")
plt.xlabel(r'$t (second)$',fontsize =20)
plt.ylabel(r'$\theta(rad)$',fontsize=20)
plt.ylim(-1.1.5)
plt.grid()
plt.legend()
plt.show()
# Out:
#   File "<ipython-input-13-5e8411558fdb>", line 10
#     plt..ylim(-1.1.5)
#         ^
# SyntaxError: invalid syntax

# %%
from IPython.html.widgets import interact, interactive
def derivSP = thetaIn[0]
omega =thetaIn[1]
dtheta = omega
domega = -(g/ell)*np.sin(theta)
return array([dtheta,domega])

def simplePendulum(th0=20.,w0=0,ell=.5,g=9.8):
    t = np.arange(0.,10+0.01,0.01)
    approx = th0*np.pi/180*np.cos(np.sqrt(g/ell)*t)
    intVals = np.aray([th0*np.pi/180,w0])
    theta = odeint(derivSP,initVals,t,args=(g,ell))
    
    plt.plot(t,approz,label='Approximate solution')
    plt.plot(ttheta[,0],label = 'Numerical soultion')
    plt.xlabel(r'$t (second)$',fontsize=20)
    plt.ylabel(r'$\theta (rad)$',fontsize =20)
    
    plt.grid()
    plt.lrgend()
    plt.show()
    
v = interact(simplePendulum,th0=(0.,90.),w0=(0.,10.),ell =(0.1,1.0)), g=(1.0,20)
# Out:
#   File "<ipython-input-14-d4704e159b72>", line 2
#     def derivSP = thetaIn[0]
#                 ^
# SyntaxError: invalid syntax

# %%
def EulerFreefall():
    tmax = 10
    dt = .1
    a = -9.81
    nsteps = int(tmax/dt)
    t = np.zeros(nsteps)
    v = np.zeros(nsteps)
    y = np.zeros(nsteps)
    
    t[0] = 0
    v[0] = 0
    
    for i in range(len(t)-1):
        t[i+1] = t[i] + dt
        v[i+1] = v[i] + dt * a
        y[i+1] = y[i] + dt * v[i]
        
    return t,v,y

te,ve,ye, = EulerFreefall()

# %%
plt.plot(te,ye,"r-",label="y(t)")
plt.plot(te,ve,"b-",label="v(t)")
plt.xlabel("time(s)",fontsize = 20)
plt.ylabel("y(t),v(t)",fontsize = 20)
plt.grid()
plt.legend(loc="best",fontsize = 20)
plt.show()

# %%
def freefall(tmax =10.,dt=.1,t0=0.,v0=46.,y0=0):
    a = -9.81
    t = np.zeros(int(tmax/dt))
    v = np.zeros(int(tmax/dt))
    y = np.zeros(int(tmax/dt))
    
    t[0] = t0
    v[0] = v0
    y[0] = y0
    
    for i in range(len(t)-1):
        t[i+1] = t[i] + dt 
        v[i+1] = v[i] + dt * a
        y[i+1] = y[i] +dt * v[i]
        
    tmax = -v0/a
    ymax = y0 +v0*tmax _ 0.5*a*tmax**2
    percentDiff = 100.*np.abs(y.max()-ymax()-ymax)/ymax
    print "ymax percentDiff = %.2f"%percentDiff
    
    plt.plot(t,y,"r-",label ="y(t)")
    plt.plot(t,v,"b-",label= "v(t)")
    plt.xlabel("time(s)",fontsize = 20)
    plt.ylabel("y(t),v(t)",fontsize = 20)
    plt.xlim(0,20.)
    plt.ylim(-100.,600.)
    plt.grid()
    plt.legend(loc="upper left", bbox_to_anchor = (1,1), fontsize = 20)
    plt.show()
# Out:
#   File "<ipython-input-21-23913d4daa4b>", line 17
#     ymax = y0 +v0*tmax _ 0.5*a*tmax**2
#                        ^
# SyntaxError: invalid syntax

# %%
v4 = interact(freefall,tmax =(1.,20.), dt =(0.01,1.,0.01),t0 =(0.,20.) v0=(10,100), y0 =(0,10))
# Out:
#   File "<ipython-input-22-d2a8476dda3b>", line 1
#     v4 = interact(freefall,tmax =(1.,20.), dt =(0.01,1.,0.01),t0 =(0.,20.) v0=(10,100), y0 =(0,10))
#                                                                             ^
# SyntaxError: invalid syntax

# %%
def EulerCromerFreefall():
    tmax = 10 # maximum time
    dt = 0.1 # time step
    a = -9.81 #g in m/s^2
    nsteps = int(tmax/dt)
    t = np.zeros(nsteps)
    v = np.zeros(nsteps)
    y = np.zeros(nsteps)
 
    # set initial conditions, redundant in this example
    t[0] = 0.
    v[0] = 0.

    for i in range(len(t)-1):
        t[i+1] = t[i] + dt
        v[i+1] = v[i] + dt * a
        y[i+1] = y[i] + dt * v[i+1] #use just calculated v value to compute y
        
    return t,v,y

# %%
tec,vec,yec = EulerCromerFreefall()

# %%
plt.plot(tec,yec,"r-",label="y(t)")
plt.plot(tec,vec,"b-",label="v(t)")
plt.xlabel("time (s)",fontsize=20)
plt.ylabel("y(t),v(t)",fontsize=20)
plt.grid()
plt.title("Euler-Cromer")
plt.legend(loc="best", fontsize=20)
plt.show()

# %%
def PPderiv(y,t):
    alpha = .7
    gamma = .5
    beta = .007
    eps =.1
    
    Zi = y[0]
    Li = y[1]
    
    dZdt = alpha*Zi - beta*Zi*Li
    dLdt = eps*beta*Zi*Li - gamma*Li
    
    return np.array([ dZdt,dLdt])

# %%
t = np.arange(0.,50.+0.1,0.1)

Z0 = 200
L0 = 50
initLZ = np.array([Z0, L0])

#pass the function deriv to the solver with initial values and integration variable
result = odeint(PPderiv,np.array([Z0,L0]),t)

Z = result[:,0]
L = result[:,1]

plt.plot(t,Z,label="Zebra population")
plt.plot(t,L,label="Lion population")
plt.xlabel("time (years)")
plt.ylabel("Population")
plt.legend()
plt.show()

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(0,2*np.pi,300)
y = np.sin(x)
y2= np.sin(x**2)

# %%
plt.plot(x, y)
plt.plot(x, y2)
plt.show()

# %%
plt.plot(x,y,linewidth=2);
plt.plot(x,y2,linewidth=2);

# %%
x = np.linspace(0,2*np.pi,50)
y = np.cos(x)
y2 = np.cos(x)
plt.plot(x,y,'o',markersize=5,color='r')
plt.plot(x,y2,'^',markersize=5, color='b')

# %%
x = np.linspace(0,2*np.pi,300)
y =np.sin(x)
y2 = np.sin(x**2)
plt.plot(x,y2)
plt.plot()
plt.grid()
plt.savefig("Example.pdf")
plt.savefig("Example.png")

# %%
# !ls -l Example.*
# Out:
# -rw-r--r--  1 rchhibbe  CALPOLY\domain^users   9685 Apr 22 12:42 Example.pdf
# -rw-r--r--  1 rchhibbe  CALPOLY\domain^users  17801 Apr 22 12:42 Example.png

# %%
x = np.linspace(-np.pi, np.pi, 56, endpoint=True)
c,s = np.cos(x), np.sin(x)

# %%
plt.figure(figsize=(8,6), dpi = 80)
plt.subplot(1,1,1)
plt.plot(x,c,color="blue",linewidth=1.0,linestyle="-")
plt.plot(x,s,color="green",linewidth=1.0,linestyle="-")
plt.xlim(-4.0,4.0)
plt.xticks(np.linspace(-4,4,9,endpoint=True))
plt.ylim(-1.0,1.0)
plt.yticks(np.linspace(-1,1,5,endpoint=True))
plt.savefig("plot_example.png",dpi=72)
plt.show()

# %%
plt.figure(figsize(10, 6), dpi=80)
plt.plot(x, c, color="blue", linewidth=2.5, linestyle"-")
plt.plot(x, s, color="red", linewidth=2.5, linestyle="-")
plt.show()
# Out:
#   File "<ipython-input-65-6ae0a3775268>", line 2
#     plt.plot(x, c, color="blue", linewidth=2.5, linestyle"-")
#                                                            ^
# SyntaxError: invalid syntax

# %% [raw]
# plt.figure(figure(figsize=(10,6),dip=80)
# plt.xlim(x.lim(x.min()* 1.1, x.max * 1.1)
# plt.ylim(c.min() * 1.1, c.max() * 1.1)
# plt.ylim(c.min() * 1.1, c.max() * 1.1)
# plt.xticks(p-np.pi,-np.pi/2,0,np.pi/2,np.pi])
# plt.yticks([-11,0,+1])
# plt.show()

# %%
plt.figure(figsize=(10,6),dpi=80)
plt.plot(x,c,color="blue",linewidth=2.5,linestyle="-")
plt.xlim(x.min()*1.1,x.max()*1.1)
plt.ylim(c.min() * 1.1, c.max() * 1.1)
ax = plt.gca()
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none)
ax.xaxis.settricks_positions(('bottom'))
ax.spines['bottom'].set_postion(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines[left'].set-positions(('data,0))
          
plt.xticks([-np.pi, -np.pi/2,o, np.pi, np.pi],[r'$-\pi$',r'$-\pi2$,r'$+\pi$'])
pl.yticks([-1,0,+1]),
          [r'$-1$',r'$0$',r'$+1$'])
plt.show()
# Out:
#   File "<ipython-input-66-f454574d1de1>", line 7
#     ax.spines['top'].set_color('none)
#                                     ^
# SyntaxError: EOL while scanning string literal

# %%
plt.figure(figure=(10,6),dpi=80)
plt.plot(x,,c,color="blue", linewidth=2.5,linestyle="-")
plt.plot(x,s,color"red",linewidth=2.5,linestyle="-")
plt.xlim(x.min()*1.1,c.max()*1.1)
plt.ylim(c.min()*1.1,c.max()*1.1)
ax =plt.gca()
ax.spines['right'].set_color('none')
ax.spines[['top'].set_position(('data',0))
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom']set_position(('data',0))
ax.yaxis.set_ticks_position(('left'))
ax.spines['left'].set_position(('data',0))
plt.xticks([-np.pi, -np.pi/2,0,np.pi/2,np.pi],)

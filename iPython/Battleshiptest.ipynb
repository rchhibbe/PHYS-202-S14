# %%
from ipythonblocks import BlockGrid

# %%
board = BlockGrid(25,25,fill=(173, 216, 230)) #I changed the color here
board
# Out:
# <style type="text/css">table.blockgrid {border: none;} .blockgrid tr {border: none;} .blockgrid td {padding: 0px;} #blocks9ea98909-ebd7-4872-9834-1a733d870d87 td {border: 1px solid white;}</style><table id="blocks9ea98909-ebd7-4872-9834-1a733d870d87" class="blockgrid"><tbody><tr><td title="Index: [0, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 3]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 4]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 5]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 6]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 7]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 8]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 9]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 10]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 11]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 12]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 13]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 14]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 15]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 16]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 17]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 18]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 19]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 20]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 21]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 22]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 23]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [0, 24]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td></tr><tr><td title="Index: [1, 0]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 1]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 2]&#10;Color: (173, 216, 230)" style="width: 20px; height: 20px;background-color: rgb(173, 216, 230);"></td><td title="Index: [1, 3]&#10;Color: (173, 216, 230)" sty ...

# %%
for x in range(5):
    board.append(["X"] * 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-984a6c880318> in <module>()
#       1 for x in range(5):
# ----> 2     board.append(["X"] * 5)
#       3
#
# AttributeError: 'BlockGrid' object has no attribute 'append'

# %%
def print_board(board):
    for row in board:
        print " ".join(row)

# %%
print "Let's play Battleship!"
print_board(board)
# Out:
# Let's play Battleship!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-1fd7744f33ea> in <module>()
#       1 print "Let's play Battleship!"
# ----> 2 print_board(board)
#
# <ipython-input-7-21d785d79319> in print_board(board)
#       1 def print_board(board):
#       2     for row in board:
# ----> 3         print " ".join(row)
#
# TypeError:

# %%
def random_row(board):
    return randint(0, len(board) - 1)

# %%
def random_row(board):
    return randint(0, len(board) - 1)

# %%
def random_row(board):
    return randint(0, len(board) - 1)

# %%
def random_col(board):
    return randint(0, len(board[0]) - 1)

# %%
def random_col2(board):
    return randint(0, len(board[0]) - 1)

# %%
def random_col3(board):
    return randint(0, len(board[0]) - 1)

# %%
#these are the different ships
ship_row = random_row(board)
Ship2/V_row = random_row(board)+random_row2(board)
Ship3/V_row = random_row(board)+random_row2(board)+random_row3(board)
ship_col = random_col(board)
Ship2_col/H =random_col(board) + random_col2(board)
Ship3_col/V =random_col(board) + random_col2(board)+random_col3(board)
print ship_row
print ship_col
# Out:
#   File "<ipython-input-29-2a0d83bf102f>", line 3
#     Ship2/V_row = random_row(board)+random_row2(board)
# SyntaxError: can't assign to operator

# %%
# Everything from here on should go in your for loop!
# Be sure to indent four spaces!
for turn in range(16):
    guess_row = int(raw_input("Guess Row:"))
    guess_col = int(raw_input("Guess Col:"))
    if guess_row == ship_row and guess_col == ship_col or guess_row ==random_row(board)+random_row2(board) and guess_col == ship_col or
    print "Congratulations! You sunk my battleship!"
# Out:
#   File "<ipython-input-21-c0439dcf3392>", line 6
#     if guess_row == ship_row and guess_col == ship_col or guess_row ==random_row(board)+random_row2(board) and guess_col == ship_col or
#                                                                                                                                        ^
# SyntaxError: invalid syntax

# %%
board [ guess_row,guess_col] = (255, 0, 0)
else:
if guess_row not in range(5) or \
   guess_col not in range(5):
# Out:
#   File "<ipython-input-35-54627417c7ad>", line 2
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
# Out:
#   File "<ipython-input-33-a09e897248c8>", line 1
#     else:
#        ^
# SyntaxError: invalid syntax

# %%
   print "Oops, that's not even in the ocean."
elif(board[guess_row][guess_col] == "X"):
        print "You guessed that one already."
# Out:
#   File "<ipython-input-36-8d137fb1f102>", line 2
#     elif(board[guess_row][guess_col] == "X"):
#        ^
# SyntaxError: invalid syntax

# %%
else:
        print "You missed my battleship!"
        board[guess_row][guess_col] = "X"
board [ guess_row,guess_col] = (0, 139, 139)
    # Print (turn + 1) here!
    print "This is the ", str(turn + 1), "th turn"
    if (board[guess_row][guess_col] == "X" and turn==15):#I increased turns here
        print "Game over"
print board
    print_board(board)
# Out:
#   File "<ipython-input-27-9f799ca63f7a>", line 2
#     >
#     ^
# SyntaxError: invalid syntax
